# %%
# %matplotlib inline

import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt
import scipy.signal as sig

from matplotlib import rcParams
rcParams['font.family'] = 'serif'

# %%
def logToMsgsValues(name):
    file = open(name)
    comments = 0
    found_christmas = False
    while True:
        line = file.readline()
        if not line:
            break
        elif line.startswith('#CLI: What are you waitin for? Christmas?'):
            found_christmas = True
        elif line.startswith('!'):
            arr = line[1:].strip().split(',')
            yield [(int(x) % 256) for x in arr[:-1]]
    if not found_christmas:
        print('ERROR! Did not find Christmas!')

def logToMsgsTypes(name):
    file = open(name)
    comments = 0
    found_christmas = False
    while True:
        line = file.readline()
        if not line:
            break
        elif line.startswith('#CLI: What are you waitin for? Christmas?'):
            found_christmas = True
        elif line.startswith(':'):
            yield line[1:].strip().split(',')[:-1]
    if not found_christmas:
        print('ERROR! Did not find Christmas!')

def logToMsgsWeakness(name):
    file = open(name)
    comments = 0
    found_christmas = False
    while True:
        line = file.readline()
        if not line:
            break
        elif line.startswith('#CLI: What are you waitin for? Christmas?'):
            found_christmas = True
        elif line.startswith('?'):
            arr = line[1:].strip().split(',')
            yield [(int(x) % 256) for x in arr[:-1]]
    if not found_christmas:
        print('ERROR! Did not find Christmas!')

# %%
def selectBytes(msgs, numMsgs):
    return np.array([item for sublist in msgs[0:numMsgs] for item in sublist])

# %%
def loadBytes(base, N, generator=logToMsgsValues):
    all_bts = []
    max_len = 0
    for i in range(1,N+1):
        msgs = list(generator(base+'_'+str(i)+'.log'))
        bts = selectBytes(msgs, len(msgs))
        max_len = len(bts) if len(bts) > max_len else max_len
        all_bts.append(np.array(bts, dtype=float))
    for i in range(0,len(all_bts)):
        all_bts[i] = np.pad(all_bts[i], (0, max_len-len(all_bts[i])), 'constant', constant_values=np.nan)
    parts = np.vstack(all_bts)
    return parts

# %%
def loadTypes(base, N):
    all_msgs = []
    for i in range(1,N+1):
        msgs = list(logToMsgsTypes(base+'_'+str(i)+'.log'))
        all_msgs.append([item for sublist in msgs for item in sublist]) # Flatten
    # Make map of all types
    all_types = []
    max_len = 0
    for msgs in all_msgs:
        max_len = len(msgs) if len(msgs) > max_len else max_len
        for msg in msgs:
            if not (msg in all_types):
                all_types.append(msg)
    all_types.sort()
    # Map all values to type index
    all_arrs = []
    for msgs in all_msgs:
        arr = np.array([all_types.index(msg) for msg in msgs])
        # Pad to maxlen
        all_arrs.append(np.pad(arr, (0, max_len-len(arr)), 'constant', constant_values=-1))
        
    return all_types, np.vstack(all_arrs)

# %%
base_dir = '../resources/logs/nodejs_test_2/'
N = 10

base_data = loadBytes(base_dir+'static',N)
diversified_data = loadBytes(base_dir+'runtime',N)

base_weak = loadBytes(base_dir+'static', N, logToMsgsWeakness)
diversified_weak = loadBytes(base_dir+'runtime', N, logToMsgsWeakness)

(base_types, base_type) = loadTypes(base_dir+'static', N)
(diversified_types, diversified_type) = loadTypes(base_dir+'runtime', N)

# %%
colormap = plt.get_cmap('rainbow')
colormap.set_bad('w')

def mask_nan(data):
    return np.ma.masked_where(np.isnan(data), data)

def plot_two_images(fignum, base_data, diversified_data):
    fig = plt.figure(fignum, figsize=(12,6))
    
    ax1pos = [0, 0.5, 1, 0.35]
    ax2pos = [0, 0, 1, 0.35]
    
    ax1 = fig.add_axes(ax1pos)    
    ax1.imshow(base_data, cmap=colormap)
    ax1.set_aspect('auto')
    ax1.set_position(ax1pos)
    
    ax1.set_title('Non-diversified instances')
    ax1.set_yticks([0,9])
    ax1.set_yticklabels(['1','10'])
    ax1.set_xticks(np.arange(0,base_data.shape[1], base_data.shape[1]/5))
    ax1.set_ylabel('Instance #')
    ax1.set_xlabel('Byte #')
    
    ax2 = fig.add_axes(ax2pos)    
    ax2.imshow(diversified_data, cmap=colormap)
    ax2.set_aspect('auto')
    ax2.set_position(ax2pos)
    
    ax2.set_title('Diversified instances')
    ax2.set_yticks([0,9])
    ax2.set_yticklabels(['1','10'])
    ax2.set_xticks([0, diversified_data.shape[1]-1])
    ax2.set_ylabel('Instance #')
    ax2.set_xlabel('Byte #')
    
    return (ax1, ax2)

# %%
def calculateCorrs(data_bytes):
    N = 100
    num_instances = data_bytes.shape[0]
    
    corr = np.zeros((num_instances, N))
    
    for i in range(0,num_instances):
        data = data_bytes[i,:]
        data = data[np.logical_not(np.isnan(data))]
        
        interaction_length = int(data.size/N)
        first_interaction = data[0:interaction_length]
        first_energy = np.dot(first_interaction, first_interaction)
        
        for j in range(0,N):
            other = data[j*interaction_length:(j+1)*interaction_length]
            corr[i,j] = np.dot(first_interaction,other)/first_energy
            
    return corr

# %%
base_corr = calculateCorrs(base_data)
diversified_corr = calculateCorrs(diversified_data)

plt.figure(100)
plt.subplot(2,1,1)
plt.plot(base_corr.T)

plt.subplot(2,1,2)
plt.plot(diversified_corr.T)

plt;

# %%
base_corr_mean = np.mean(base_corr, axis=0)
diversified_corr_mean = np.mean(diversified_corr, axis=0)

plt.figure(101)
plt.plot(base_corr_mean)
plt.plot(diversified_corr_mean)

# %%
plot_two_images(1, mask_nan(base_data), mask_nan(diversified_data))
# Out:
# (<matplotlib.axes._axes.Axes at 0x1e4f17d6978>,
#  <matplotlib.axes._axes.Axes at 0x1e4f282f550>)

# %%
base_weak_type = np.ma.masked_where(base_weak < 1, base_type)

diversified_weak_type = diversified_weak.copy()
#diversified_weak_type[np.isnan(diversified_weak_type)] = 0
#diversified_weak_type = np.ma.masked_where(diversified_weak_type < 1, diversified_type)

plot_two_images(2, base_weak_type, diversified_weak_type)
# Out:
# C:\Users\jakobho\AppData\Local\Continuum\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: RuntimeWarning: invalid value encountered in less
#   """Entry point for launching an IPython kernel.
# (<matplotlib.axes._axes.Axes at 0x1c89aaebdd8>,
#  <matplotlib.axes._axes.Axes at 0x1c89aa7d2b0>)

# %%
plt.figure(100, figsize=(14,10))

N = 10

for i in range(0,N):
   single = base_data[i,:]
   single[np.isnan(single)] = 0
   f, P = sig.periodogram(single)
   plt.plot(f,P)
    
plt.show()

plt.figure(101, figsize=(14,10))

for i in range(0,N):
   single = diversified_data[i,:]
   single[np.isnan(single)] = 0
   f, P = sig.periodogram(single)
   plt.plot(f,P)
    
plt.show()

# i = 1
# single = diversified_data[i,:]
# single[np.isnan(single)] = 0
# f, P = sig.periodogram(single)
# plt.plot(f,P)
